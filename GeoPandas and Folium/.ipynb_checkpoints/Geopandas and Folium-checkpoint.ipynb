# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from geopandas) (1.2.4)
# Collecting shapely>=1.7.1
#   Downloading shapely-2.0.2-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting fiona>=1.8.19
#   Downloading fiona-1.9.5-cp38-cp38-win_amd64.whl (22.9 MB)
# Collecting pyproj>=3.0.1
#   Downloading pyproj-3.5.0-cp38-cp38-win_amd64.whl (5.1 MB)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from geopandas) (20.9)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (1.15.0)
# Requirement already satisfied: importlib-metadata in c:\users\lenovo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (3.10.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (2020.12.5)
# Collecting click~=8.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fiona>=1.8.19->geopandas) (20.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.1.0->geopandas) (1.20.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from packaging->geopandas) (2.4.7)
# Installing collected packages: click, cligj, click-plugins, shapely, pyproj, fiona, geopandas
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# Successfully installed click-8.1.7 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.5 geopandas-0.13.2 pyproj-3.5.0 shapely-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("CovidDIY.geojson")
gdf.head()
# Out:
#   Kabupaten/Kota  Positif  Sembuh  Meninggal  Odp  Pdp Terakhir Update  \
# 0     Yogyakarta        4    True      False  195   20      26-03-2020
# 1         Sleman        8   False      False  303   23      26-03-2020
# 2    Kulon Progo        1   False      False   72    5      26-03-2020
# 3   Gunung Kidul        1   False      False  292    4      26-03-2020
# 4         Bantul        2   False      False  157   28      26-03-2020
#
#                                             geometry
# 0  POLYGON ((110.40146 -7.83521, 110.39887 -7.837...
# 1  POLYGON ((110.32395 -7.71929, 110.32224 -7.718...
# 2  POLYGON ((110.17369 -7.82435, 110.17277 -7.825...
# 3  POLYGON ((110.56855 -8.07854, 110.56648 -8.083...
# 4  POLYGON ((110.35795 -7.90765, 110.35655 -7.909...

# %%
gdf = gdf[['Kabupaten/Kota', 'Positif', 'Sembuh', 'Meninggal','Odp','Pdp','Terakhir Update', 'geometry']].fillna(0)

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\lenovo\anaconda3\lib\site-packages (0.15.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jinja2>=2.9 in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: xyzservices in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (2023.10.1)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from folium) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->folium) (2.10)

# %%
pip install mapclassify
# Out:
# Collecting mapclassifyNote: you may need to restart the kernel to use updated packages.
#
#   Downloading mapclassify-2.6.0-py3-none-any.whl (40 kB)
# Requirement already satisfied: numpy>=1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from mapclassify) (1.20.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mapclassify) (1.6.2)
# Requirement already satisfied: pandas>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mapclassify) (1.2.4)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from mapclassify) (2.5)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from mapclassify) (0.24.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from networkx->mapclassify) (5.0.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (1.0.1)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.0

# %%
import folium
m = gdf.explore(column="Kabupaten/Kota", name="Kabupaten")
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3895f8e0d5acac6b2e2597e7de3e3ffc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Kabupaten/Kota&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Kabupaten/Kota&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Bantul&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;Gunung Kidul&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;Kulon Progo&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#c7c7c7&#x27;&gt;&lt;/span&gt;Sleman&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Yogyakarta&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3895f8e0d5acac6b2e2597e7de3e3ffc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3895f8e0d5acac6b2e2597e7de3e3ffc = L.map(
#                 &quot;map_3895f8e0d5acac6b2e2597e7de3e3ffc&quot;,
#                 {
#                     center: [-7.894756668848486, 110.34709248095078],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3895f8e0d5acac6b2e2597e7de3e3ffc);
#
#
#
#
#
#             var tile_layer_a8cc49d1337f9d0699c36a27ec136e73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a8cc49d1337f9d0699c36a27ec136e73.addTo(map_3895f8e0d5acac6b2e2597e7de3e3ffc);
#
#
#             map_3895f8e0d5acac6b2e2597e7de3e3ffc.fitBounds(
#                 [[-8.127545976220318, 110.12001122826189], [-7.661967361476654, 110.57417373363968]],
#                 {}
#             );
#
#
#         function geo_json_c8cd0dbe2aab4290aeeb78a75e23e938_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#9edae5&quot;, &quot;fillColor&quot;: &quot;#9edae5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#c7c7c7&quot;, &quot;fillColor&quot;: &quot;#c7c7c7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:

# %%
m.save("DC Map.html")

# %%
m = folium.Map(
    location=[-7.794914855530829, 110.37106715251684],
    tiles='Stamen Terrain',
    attr='Attribution Text Here',  # Ganti dengan teks attribusi yang sesuai
    zoom_start=11
)

# Sisanya dari kode yang sebelumnya
tooltip = folium.features.GeoJsonTooltip(
    fields=['Kabupaten/Kota', 'Positif'],
    aliases=["Wilayah", "Terkena Covid"],
    labels=True,
    sticky=False
)
folium.GeoJson(gdf, tooltip=tooltip).add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4719d3be17f8df6eb4fcbcb61357815 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4719d3be17f8df6eb4fcbcb61357815&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4719d3be17f8df6eb4fcbcb61357815 = L.map(
#                 &quot;map_b4719d3be17f8df6eb4fcbcb61357815&quot;,
#                 {
#                     center: [-7.794914855530829, 110.37106715251684],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c60e9a36a9549e9b26b2fe026f0854e = L.tileLayer(
#                 &quot;Stamen Terrain&quot;,
#                 {&quot;attribution&quot;: &quot;Attribution Text Here&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c60e9a36a9549e9b26b2fe026f0854e.addTo(map_b4719d3be17f8df6eb4fcbcb61357815);
#
#
#
#         function geo_json_d2baf58eb786adaece9720472ed2b35e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d2baf58eb786adaece9720472ed2b35e = L.geoJson(null, {
#                 onEachFeature: geo_json_d2baf58eb786adaece9720472ed2b35e_onEachFeature,
#
#         });
#
#         function geo_json_d2baf58eb786adaece9720472ed2b35e_add (data) {
#             geo_json_d2baf58eb786adaece9720472ed2b35e
#                 .addData(data);
#         }
#             geo_json_d2baf58eb786adaece9720472ed2b35e_add({&quot;bbox&quot;: [110.12001122826189, -8.127545976220318, 110.57417373363968, -7.661967361476654], &quot;features&quot;: [{&quot;bbox&quot;: [110.31065443544396, -7.850198175365264, 110.4176845713078, -7.744157599759768], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[110.40146195243763, -7.835213873668118], [110.39887132702141, -7.837548712613662], [110.39613210306884, -7.839710688077402], [110.39325601035736, -7.841690544907409], [110.39025536475755, -7.843479807706816], [110.38714301549454, -7.845070817081107], [110.3839322901257, -7.846456762393719], [110.38063693746996, -7.847631710890434], [110.37727106873326, -7.848590633068589], [110.37384909708234, -7.849329424183012], [110.3703856759251, -7.849844921797205], [110.36689563616272, -7.850134919305008], [110.3633939226812, -7.850198175365264], [110.3598955303553, -7.850034419209262], [110.356415439838, -7.849644351798442], [110.35296855341122, -7.84902964282737], [110.34956963117179, -7.8481929235848], [110.34623322782653, -7.847137775703138], [110.34297363036683, -7.845868715844255], [110.33980479688938, -7.844391176386777], [110.33674029682567, -7.842711482197057], [110.33379325283538, -7.840836823582781], [110.33097628461336, -7.8387752255443], [110.32830145485002, -7.836535513454677], [110.325780217577, -7.834127275314636], [110.32342336911941, -7.831560820743256], [110.3212410018642, -7.828847136879132], [110.31924246104292, -7.825997841380096], [110.31743630471426, -7.823025132721817], [110.31583026711687, -7.819941738007395], [110.31443122555032, -7.81676085851059], [110.31324517092536, -7.8134961131852], [110.31227718211004, -7.810161480381771], [110.31153140418101, -7.806771238020637], [110.31101103067388, -7.803339902477001], [110.31071828990788, -7.799882166439259], [110.31065443544396, -7.796412836006401], [110.31081974071671, -7.792946767293601], [110.31121349786353, -7.789498802817325], [110.31183402075595, -7.786083707932375], [110.31267865221962, -7.782716107593152], [110.31374377541296, -7.779410423710114], [110.31502482931492, -7.776180813370019], [110.31651632825607, -7.773041108184866], [110.31821188540893, -7.770004755029754], [110.32010424013747, -7.767084758424029], [110.32218528908818, -7.764293624803022], [110.32444612089003, -7.761643308919795], [110.32687705431412, -7.759145162607106], [110.32946767973034, -7.756809886119799], [110.33220690368293, -7.754647482266786], [110.3350829963944, -7.752667213529856], [110.33808364199419, -7.750877562353705], [110.34119599125721, -7.749286194778087], [110.34440671662607, -7.747899927568486], [110.34770206928181, -7.74672469898686], [110.3510679380185, -7.745765543328196], [110.35448990966943, -7.745026569332582], [110.35795333082666, -7.744510942565665], [110.36144337058904, -7.744220871843432], [110.36494508407056, -7.744157599759768], [110.36844347639645, -7.74432139735754], [110.37192356691375, -7.744711562966234], [110.37537045334054, -7.74532642521109], [110.37876937557996, -7.746163350180804], [110.38210577892521, -7.747218752722918], [110.38536537638494, -7.748488111818258], [110.38853420986239, -7.749965989968186], [110.3915987099261, -7.751646056511226], [110.39454575391639, -

# %%
m = folium.Map(
    location=[-7.794914855530829, 110.37106715251684],
    tiles='Stamen Terrain',
    attr='Attribution Text Here',  # Ganti dengan teks attribusi yang sesuai
    zoom_start=11
)

cpleth = folium.Choropleth(gdf, data=gdf, key_on='feature.properties.NAME',
                          columns=['NAME', 'perc_change'],
                          fill_color="RdYlGn",
                          legend_name="Percent Change, 2012-2021", 
                          name="DC Neighborhood Clusters")
cpleth.geojson.add_child(tooltip)
cpleth.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-72f3af49feb0> in <module>
#       6 )
#       7
# ----> 8 cpleth = folium.Choropleth(gdf, data=gdf, key_on='feature.properties.NAME',
#       9                           columns=['NAME', 'perc_change'],
#      10                           fill_color="RdYlGn",
#
# ~\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1495             # This is a pd.DataFrame
#    1496             assert columns is not None
# -> 1497             color_data = data.set_index(columns[0])[columns[1]].to_dict()  # type: ignore
#    1498         elif hasattr(data, "to_dict"):
#    1499             # This is a pd.Series
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['NAME'] are in the columns"
